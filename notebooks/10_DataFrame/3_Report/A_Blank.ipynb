# %% [markdown]
# ## Load dataset

# %%
# Out:
#                      price   energy        cost  year  month  day  hour  \
# datetime
# 2023-01-01 00:00:00   0.00  14039.8       0.000  2023      1    1     0
# 2023-01-01 01:00:00   0.00  13581.2       0.000  2023      1    1     1
# ...                    ...      ...         ...   ...    ...  ...   ...
# 2023-12-31 22:00:00  74.74  13223.4  988316.916  2023     12   31    22
# 2023-12-31 23:00:00  71.96  12659.1  910948.836  2023     12   31    23
#
#                      dayofweek
# datetime
# 2023-01-01 00:00:00          6
# 2023-01-01 01:00:00          6
# ...                        ...
# 2023-12-31 22:00:00          6
# 2023-12-31 23:00:00          6
#
# [8760 rows x 8 columns]

# %% [markdown]
# ## Visual report

# %% [markdown]
# ### Area plot

# %% [markdown]
# ### Export to Excel

# %% [markdown]
# ## Pivot table

# %% [markdown]
# ### Aggregation

# %% [markdown]
# ### Refactor

# %%
# Out:
# <style type="text/css">
# #T_394a8_row0_col0, #T_394a8_row1_col11, #T_394a8_row6_col11, #T_394a8_row15_col4, #T_394a8_row15_col10, #T_394a8_row23_col10 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_394a8_row0_col1 {
#   background-color: #549cc7;
#   color: #f1f1f1;
# }
# #T_394a8_row0_col2, #T_394a8_row12_col2, #T_394a8_row12_col5, #T_394a8_row13_col5, #T_394a8_row16_col8, #T_394a8_row17_col2 {
#   background-color: #99b8d8;
#   color: #000000;
# }
# #T_394a8_row0_col3, #T_394a8_row1_col2, #T_394a8_row3_col7, #T_394a8_row16_col9 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_394a8_row0_col4, #T_394a8_row3_col8 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_394a8_row0_col5, #T_394a8_row13_col6 {
#   background-color: #8fb4d6;
#   color: #000000;
# }
# #T_394a8_row0_col6, #T_394a8_row9_col9 {
#   background-color: #6da6cd;
#   color: #f1f1f1;
# }
# #T_394a8_row0_col7 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# ## Replication
